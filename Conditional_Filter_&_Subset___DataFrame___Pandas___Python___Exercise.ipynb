# %% [markdown]
# # **Conditional Filter & Subset | DataFrame | Pandas | Python | Solved Exercise**

# %% [markdown]
# # **Import library**

# %%
import pandas as pd

# %% [markdown]
# # **Problem 1. Import Titanic dataset and store as the pandas dataframe with name titanic**

# %% [markdown]
# # **Solution 1.**

# %%
titanic = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.csv')

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %% [markdown]
# # **Problem 2. Create a new dataframe (female) from titanic of female passengers only and display first 8 rows**

# %% [markdown]
# # **Solution 2.**

# %%
female = titanic.loc[titanic['sex']=='female']

# %%
female.head(8)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 2        1         0                       Allison, Miss. Helen Loraine
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
#
#        sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# 0   female  29.0      0      0     24160  211.3375       B5        S    2
# 2   female   2.0      1      2    113781  151.5500  C22 C26        S  NaN
# 4   female  25.0      1      2    113781  151.5500  C22 C26        S  NaN
# ...

# %% [markdown]
# # **Problem 3. Count number of female survived and not survived**

# %% [markdown]
# # **Solution 3.**

# %%
female['survived'].value_counts()
# Out:
# 1    339
# 0    127
# Name: survived, dtype: int64

# %%
female.loc[:,['survived']].value_counts()
# Out:
# survived
# 1           339
# 0           127
# dtype: int64

# %% [markdown]
# # **Problem 4. Count number of female survived and not survived as per passenger class**

# %% [markdown]
# # ***Solution 4.***

# %%
female[['survived','pclass']].value_counts()
# Out:
# survived  pclass
# 1         1         139
# 0         3         110
# 1         3         106
#           2          94
# 0         2          12
#           1           5
# dtype: int64

# %%
female.groupby(['survived','pclass']).count()
# Out:
#                  name  sex  age  sibsp  parch  ticket  fare  cabin  embarked  \
# survived pclass
# 0        1          5    5    5      5      5       5     5      5         5
#          2         12   12   11     12     12      12    12      1        12
#          3        110  110   80    110    110     110   110      2       110
# 1        1        139  139  128    139    139     139   139    116       137
#          2         94   94   92     94     94      94    94     12        94
#          3        106  106   72    106    106     106   106      5       106
#
#                  boat  body  home.dest
# survived pclass
# 0        1          0     0          5
#          2          0     1         12
#          3          1     7         30
# 1        1        138     0        116
#          2         86     0         92
#          3         94     0         33

# %% [markdown]
# # **Problem 5. Select passengers with age > 18 years**

# %% [markdown]
# # ***Solution 5.***

# %%
titanic.loc[titanic['age']>18, :]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# ...      ...       ...                                              ...
# 1299       3         0                              Yasbeck, Mr. Antoni
# 1301       3         0                             Youseff, Mr. Gerious
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# # **Problem 6. Select passengers with age > 18 years and female**

# %% [markdown]
# # ***Solution 6.***

# %%
titanic.loc[(titanic['age']>18) & (titanic['sex']=='female'), :]
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# ...      ...       ...                                                ...
# 1261       3         1                             Turkula, Mrs. (Hedwig)
# 1267       3         0  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 1276       3         0  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 1286       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                   Wilkes, Mrs. James (Ellen Needs)
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# # **Problem 7. Select passengers with age > 18 years and female and travelling by first class**

# %% [markdown]
# # ***Solution 7.***

# %%
titanic.loc[(titanic['age']>18) & (titanic['sex']=='female') & (titanic['pclass']==1), :]
# Out:
#      pclass  survived                                             name  \
# 0         1         1                    Allen, Miss. Elisabeth Walton
# 4         1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6         1         1                Andrews, Miss. Kornelia Theodosia
# 8         1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 12        1         1                    Aubart, Mme. Leontine Pauline
# ..      ...       ...                                              ...
# 311       1         1       Wick, Mrs. George Dennick (Mary Hitchcock)
# 314       1         1     Widener, Mrs. George Dunton (Eleanor Elkins)
# 315       1         1                         Willard, Miss. Constance
# 319       1         1                        Wilson, Miss. Helen Alice
# 322       1         1                         Young, Miss. Marie Grice
#
#         sex   age  sibsp  parch    ticket      fare    cabin embarked  boat  \
# ...

# %% [markdown]
# # **Problem 8. Select passengers with age > 18 years and female and travelling by first class and calculate their mean age**

# %% [markdown]
# # ***Solution 8.***

# %%
titanic.loc[(titanic['age']>18) & (titanic['sex']=='female') & (titanic['pclass']==1), 'age'].mean()
# Out:
# 39.358333333333334

# %% [markdown]
# # **Problem 9. Select passengers with age > 18 years or female and travelling by first class**

# %% [markdown]
# # ***Solution 9.***

# %%
titanic.loc[(titanic['age'] > 18) | (titanic['sex']=='female') & (titanic['pclass']==1)]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                              Anderson, Mr. Harry
# ...      ...       ...                                              ...
# 1299       3         0                              Yasbeck, Mr. Antoni
# 1301       3         0                             Youseff, Mr. Gerious
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# # **Problem 10. Select passengers with age > 18 years or female and travelling by first class and calculate their mean age**

# %% [markdown]
# # ***Solution 10.***

# %%
titanic.loc[(titanic['age'] > 18) | (titanic['sex']=='female') & (titanic['pclass']==1), 'age'].mean()
# Out:
# 33.89722863741339

# %% [markdown]
# # 😀
#
# ---
